# %%
text= """The Rise of Gemini’s Nano Banana Trend
In today’s fast-paced digital age, trends often emerge overnight and capture the imagination of millions across the globe. One of the latest to sweep through social media platforms is the “Nano Banana” trend, powered by Google’s Gemini AI. This phenomenon combines the allure of self-expression with cutting-edge artificial intelligence, allowing ordinary users to turn simple selfies into hyper-realistic, toy-like figurines. The craze has gone viral, and its popularity speaks volumes about how people engage with technology, creativity, and identity in the 21st century.
At its core, the Nano Banana trend involves using Gemini’s AI to transform personal photos into miniature 3D-style collectibles. With a simple prompt and image input, users can generate strikingly detailed images of themselves as action figures, vintage portraits, or even characters inspired by pop culture. The process is easy to use and requires no technical background, which makes it accessible to millions. This democratization of art and design is one of the primary reasons the trend has spread so quickly.
The appeal of Nano Banana lies in several key factors. First, there is nostalgia. Many of the generated images resemble retro collectibles or vintage photography, evoking a sense of familiarity and warmth. Second, the trend taps into the human desire for self-expression. People enjoy seeing alternative versions of themselves in playful, exaggerated, or stylized formats. It becomes a fun way of reimagining one’s identity. Third, the shareability of these creations makes them ideal for social media platforms like Instagram and X (formerly Twitter). The more creative and unusual the output, the more likely it is to be reshared, fueling the cycle of virality.
The positive impacts of the trend are notable. It has encouraged widespread creativity, enabling users to experiment with design, aesthetics, and imaginative storytelling. Furthermore, it showcases the power of artificial intelligence as a tool for innovation, allowing people to engage with technology in fun and meaningful ways. Beyond individual use, the trend has influenced online communities, fostering a sense of togetherness as people exchange prompts, ideas, and humorous takes on the format.
However, like many AI-driven trends, Nano Banana comes with challenges. The most pressing concern is privacy. Users often upload personal photos to create their figurines, raising questions about data security and ownership of AI-generated outputs. There is also the potential for misuse, as such technology can be adapted for creating misleading images or deepfakes. Additionally, copyright concerns arise when prompts involve famous artworks or characters. Another challenge is inclusivity. AI models are only as balanced as the data they are trained on, meaning biases in representation may persist in outputs. Finally, there is the issue of oversaturation. While trends burn bright, they often fade quickly once audiences tire of repetitive content.
In a broader sense, the Nano Banana trend reflects deeper cultural shifts. It challenges traditional notions of art by blurring the line between human creativity and machine-generated work. It also influences online identity, as people increasingly use stylized, AI-crafted images to represent themselves. This raises questions about authenticity and the future of digital self-expression.
In conclusion, Gemini’s Nano Banana trend is more than just a fleeting craze; it is a window into the evolving relationship between humans and artificial intelligence. While it sparks joy, nostalgia, and creativity, it also compels society to confront issues of privacy, ownership, and representation. Whether it fades or evolves into something larger, the trend demonstrates how AI continues to reshape culture in surprising and impactful ways."""

# %%
text
# Out:
# 'The Rise of Gemini’s Nano Banana Trend \nIn today’s fast-paced digital age, trends often emerge overnight and capture the imagination of millions across the globe. One of the latest to sweep through social media platforms is the “Nano Banana” trend, powered by Google’s Gemini AI. This phenomenon combines the allure of self-expression with cutting-edge artificial intelligence, allowing ordinary users to turn simple selfies into hyper-realistic, toy-like figurines. The craze has gone viral, and its popularity speaks volumes about how people engage with technology, creativity, and identity in the 21st century.\nAt its core, the Nano Banana trend involves using Gemini’s AI to transform personal photos into miniature 3D-style collectibles. With a simple prompt and image input, users can generate strikingly detailed images of themselves as action figures, vintage portraits, or even characters inspired by pop culture. The process is easy to use and requires no technical background, which m
# ...

# %% [markdown]
# #Natural Language Took Kit - nltk package

# %%
pip install nltk

# %%
import nltk

# %% [markdown]
# #Tokenization

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
 nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
Sentences=sent_tokenize(text)

# %% [markdown]
# # Sentence Segmentation

# %%
Sentences
# Out:
# ['The Rise of Gemini’s Nano Banana Trend \nIn today’s fast-paced digital age, trends often emerge overnight and capture the imagination of millions across the globe.',
#  'One of the latest to sweep through social media platforms is the “Nano Banana” trend, powered by Google’s Gemini AI.',
#  'This phenomenon combines the allure of self-expression with cutting-edge artificial intelligence, allowing ordinary users to turn simple selfies into hyper-realistic, toy-like figurines.',
#  'The craze has gone viral, and its popularity speaks volumes about how people engage with technology, creativity, and identity in the 21st century.',
#  'At its core, the Nano Banana trend involves using Gemini’s AI to transform personal photos into miniature 3D-style collectibles.',
#  'With a simple prompt and image input, users can generate strikingly detailed images of themselves as action figures, vintage portraits, or even characters inspired by pop culture.',
# ...

# %% [markdown]
# #Word segmentation

# %%
words=word_tokenize(text)

# %%
words
# Out:
# ['The',
#  'Rise',
#  'of',
#  'Gemini',
#  '’',
#  's',
#  'Nano',
#  'Banana',
#  'Trend',
#  'In',
#  'today',
#  '’',
#  's',
#  'fast-paced',
#  'digital',
#  'age',
#  ',',
#  'trends',
#  'often',
#  'emerge',
#  'overnight',
#  'and',
#  'capture',
#  'the',
#  'imagination',
#  'of',
#  'millions',
#  'across',
#  'the',
#  'globe',
#  '.',
#  'One',
#  'of',
#  'the',
#  'latest',
#  'to',
#  'sweep',
#  'through',
#  'social',
#  'media',
#  'platforms',
#  'is',
#  'the',
#  '“',
#  'Nano',
#  'Banana',
#  '”',
#  'trend',
#  ',',
#  'powered',
#  'by',
#  'Google',
#  '’',
#  's',
#  'Gemini',
#  'AI',
#  '.',
#  'This',
#  'phenomenon',
#  'combines',
#  'the',
#  'allure',
#  'of',
#  'self-expression',
#  'with',
#  'cutting-edge',
#  'artificial',
#  'intelligence',
#  ',',
#  'allowing',
#  'ordinary',
#  'users',
#  'to',
#  'turn',
#  'simple',
#  'selfies',
#  'into',
#  'hyper-realistic',
#  ',',
#  'toy-like',
#  'figurines',
#  '.',
#  'The',
#  'craze',
# ...

# %% [markdown]
# #lower case and Removing stop words

# %%
lower_sent=[sentence.lower() for sentence in Sentences]

# %%
lower_sent
# Out:
# ['the rise of gemini’s nano banana trend \nin today’s fast-paced digital age, trends often emerge overnight and capture the imagination of millions across the globe.',
#  'one of the latest to sweep through social media platforms is the “nano banana” trend, powered by google’s gemini ai.',
#  'this phenomenon combines the allure of self-expression with cutting-edge artificial intelligence, allowing ordinary users to turn simple selfies into hyper-realistic, toy-like figurines.',
#  'the craze has gone viral, and its popularity speaks volumes about how people engage with technology, creativity, and identity in the 21st century.',
#  'at its core, the nano banana trend involves using gemini’s ai to transform personal photos into miniature 3d-style collectibles.',
#  'with a simple prompt and image input, users can generate strikingly detailed images of themselves as action figures, vintage portraits, or even characters inspired by pop culture.',
# ...

# %%
lower_word=[word.lower() for word in words]

# %%
lower_word
# Out:
# ['the',
#  'rise',
#  'of',
#  'gemini',
#  '’',
#  's',
#  'nano',
#  'banana',
#  'trend',
#  'in',
#  'today',
#  '’',
#  's',
#  'fast-paced',
#  'digital',
#  'age',
#  ',',
#  'trends',
#  'often',
#  'emerge',
#  'overnight',
#  'and',
#  'capture',
#  'the',
#  'imagination',
#  'of',
#  'millions',
#  'across',
#  'the',
#  'globe',
#  '.',
#  'one',
#  'of',
#  'the',
#  'latest',
#  'to',
#  'sweep',
#  'through',
#  'social',
#  'media',
#  'platforms',
#  'is',
#  'the',
#  '“',
#  'nano',
#  'banana',
#  '”',
#  'trend',
#  ',',
#  'powered',
#  'by',
#  'google',
#  '’',
#  's',
#  'gemini',
#  'ai',
#  '.',
#  'this',
#  'phenomenon',
#  'combines',
#  'the',
#  'allure',
#  'of',
#  'self-expression',
#  'with',
#  'cutting-edge',
#  'artificial',
#  'intelligence',
#  ',',
#  'allowing',
#  'ordinary',
#  'users',
#  'to',
#  'turn',
#  'simple',
#  'selfies',
#  'into',
#  'hyper-realistic',
#  ',',
#  'toy-like',
#  'figurines',
#  '.',
#  'the',
#  'craze',
# ...

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words=set(stopwords.words("english"))

# %%
clean_data=[word for word in words if word.lower() not in stop_words and word.isalpha()]

# %%
len(clean_data)
# Out:
# 351

# %%
len(stop_words)
# Out:
# 198

# %%
len(words)
# Out:
# 678

# %% [markdown]
# #Stemming

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %%
Stemmer=PorterStemmer()

# %%
Stemmed_data=[Stemmer.stem(word) for word in clean_data]
Stemmed_data
# Out:
# ['rise',
#  'gemini',
#  'nano',
#  'banana',
#  'trend',
#  'today',
#  'digit',
#  'age',
#  'trend',
#  'often',
#  'emerg',
#  'overnight',
#  'captur',
#  'imagin',
#  'million',
#  'across',
#  'globe',
#  'one',
#  'latest',
#  'sweep',
#  'social',
#  'media',
#  'platform',
#  'nano',
#  'banana',
#  'trend',
#  'power',
#  'googl',
#  'gemini',
#  'ai',
#  'phenomenon',
#  'combin',
#  'allur',
#  'artifici',
#  'intellig',
#  'allow',
#  'ordinari',
#  'user',
#  'turn',
#  'simpl',
#  'selfi',
#  'figurin',
#  'craze',
#  'gone',
#  'viral',
#  'popular',
#  'speak',
#  'volum',
#  'peopl',
#  'engag',
#  'technolog',
#  'creativ',
#  'ident',
#  'centuri',
#  'core',
#  'nano',
#  'banana',
#  'trend',
#  'involv',
#  'use',
#  'gemini',
#  'ai',
#  'transform',
#  'person',
#  'photo',
#  'miniatur',
#  'collect',
#  'simpl',
#  'prompt',
#  'imag',
#  'input',
#  'user',
#  'gener',
#  'strikingli',
#  'detail',
#  'imag',
#  'action',
#  'figur',
#  'vintag',
# ...

# %%
lemmatizer=WordNetLemmatizer()

# %%
lemmatized_data=[lemmatizer.lemmatize(word) for word in clean_data]
lemmatized_data
# Out:
# ['Rise',
#  'Gemini',
#  'Nano',
#  'Banana',
#  'Trend',
#  'today',
#  'digital',
#  'age',
#  'trend',
#  'often',
#  'emerge',
#  'overnight',
#  'capture',
#  'imagination',
#  'million',
#  'across',
#  'globe',
#  'One',
#  'latest',
#  'sweep',
#  'social',
#  'medium',
#  'platform',
#  'Nano',
#  'Banana',
#  'trend',
#  'powered',
#  'Google',
#  'Gemini',
#  'AI',
#  'phenomenon',
#  'combine',
#  'allure',
#  'artificial',
#  'intelligence',
#  'allowing',
#  'ordinary',
#  'user',
#  'turn',
#  'simple',
#  'selfies',
#  'figurine',
#  'craze',
#  'gone',
#  'viral',
#  'popularity',
#  'speaks',
#  'volume',
#  'people',
#  'engage',
#  'technology',
#  'creativity',
#  'identity',
#  'century',
#  'core',
#  'Nano',
#  'Banana',
#  'trend',
#  'involves',
#  'using',
#  'Gemini',
#  'AI',
#  'transform',
#  'personal',
#  'photo',
#  'miniature',
#  'collectible',
#  'simple',
#  'prompt',
#  'image',
#  'input',
#  'user',
#  'generate',
#  'strikingly',
# ...

# %% [markdown]
# #N grams

# %%
from nltk import ngrams

# %%
uni_gram=list(ngrams(clean_data,1))
uni_gram
# Out:
# [('Rise',),
#  ('Gemini',),
#  ('Nano',),
#  ('Banana',),
#  ('Trend',),
#  ('today',),
#  ('digital',),
#  ('age',),
#  ('trends',),
#  ('often',),
#  ('emerge',),
#  ('overnight',),
#  ('capture',),
#  ('imagination',),
#  ('millions',),
#  ('across',),
#  ('globe',),
#  ('One',),
#  ('latest',),
#  ('sweep',),
#  ('social',),
#  ('media',),
#  ('platforms',),
#  ('Nano',),
#  ('Banana',),
#  ('trend',),
#  ('powered',),
#  ('Google',),
#  ('Gemini',),
#  ('AI',),
#  ('phenomenon',),
#  ('combines',),
#  ('allure',),
#  ('artificial',),
#  ('intelligence',),
#  ('allowing',),
#  ('ordinary',),
#  ('users',),
#  ('turn',),
#  ('simple',),
#  ('selfies',),
#  ('figurines',),
#  ('craze',),
#  ('gone',),
#  ('viral',),
#  ('popularity',),
#  ('speaks',),
#  ('volumes',),
#  ('people',),
#  ('engage',),
#  ('technology',),
#  ('creativity',),
#  ('identity',),
#  ('century',),
#  ('core',),
#  ('Nano',),
#  ('Banana',),
#  ('trend',),
#  ('involves',),
#  ('using',),
#  ('Gemini',),
# ...

# %%
bi_gram=list(ngrams(clean_data,2))

# %%
tri_gram=list(ngrams(clean_data,3))
